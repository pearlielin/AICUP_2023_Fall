# %% [markdown]
# <a href="https://colab.research.google.com/github/pearlielin/AICUP_2023_Fall/blob/main/aicup_submit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# setting
stage_1_model_path = 'model_36.39.pt'
stage_1_training = False

# %%
#download
# !gdown https://drive.google.com/uc?id=11PRvJv4TnSYSxFIO2WJt4Yergcbr0kKB -O answer.txt #answer.txt
# !gdown https://drive.google.com/uc?id=15XvXgN6yWugq5ZWmn1DTIcZH8RdxgtPL -O First_Phase_ReleaseCorrection.zip #first
# !gdown https://drive.google.com/uc?id=1p8z3tqxATXjyUr4VbXzCj3BtpzgYEnLq -O Second_Phase_Dataset.zip #second
# !gdown https://drive.google.com/uc?id=1miRbkNE82ece_Qe3SpL8bZlWTzemIQ3d -O opendid_test.zip #openid_test
# !gdown https://drive.google.com/uc?id=1j9l0JIVoVqs6M3qnuvqvExK-0GK00ly_ -O model_36.39.pt #model
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11PRvJv4TnSYSxFIO2WJt4Yergcbr0kKB
# To: /content/answer.txt
# 100% 336k/336k [00:00<00:00, 141MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=15XvXgN6yWugq5ZWmn1DTIcZH8RdxgtPL
# To: /content/First_Phase_ReleaseCorrection.zip
# 100% 3.55M/3.55M [00:00<00:00, 163MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1p8z3tqxATXjyUr4VbXzCj3BtpzgYEnLq
# To: /content/Second_Phase_Dataset.zip
# 100% 1.32M/1.32M [00:00<00:00, 58.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1miRbkNE82ece_Qe3SpL8bZlWTzemIQ3d
# To: /content/opendid_test.zip
# 100% 3.47M/3.47M [00:00<00:00, 177MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1j9l0JIVoVqs6M3qnuvqvExK-0GK00ly_
# To: /content/model_36.39.pt
# 100% 496M/496M [00:10<00:00, 46.9MB/s]

# %%
# stage 1 setting (try different pretrain model)

# plm = 'bert-base-uncased'
stage_1_plm = 'roberta-base'

# %%
#package install
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)

# %%
#unzip data
# !unzip First_Phase_ReleaseCorrection.zip
# !unzip Second_Phase_Dataset.zip
# !unzip opendid_test.zip
# Out:
# Archive:  First_Phase_ReleaseCorrection.zip
#    creating: First_Phase_Release(Correction)/
#   inflating: First_Phase_Release(Correction)/answer.txt
#    creating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/10.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/100.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/101.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/102.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/103.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/104.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/105.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/106.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/107.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/108.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/109.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/11.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/110.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/112.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/113.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/114.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/115.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/116.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/117.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/118.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/119.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/12.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/120.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/121.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/122.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/123.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/124.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/125.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/126.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/127.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/128.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/129.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/13.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/130.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/131.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/132.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/133.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/134.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/135.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/136.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/137.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/138.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/139.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/14.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/140.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/141.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/142.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/143.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/144.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/145.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/146.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/147.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/148.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/149.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/15.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/150.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/151.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/152.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/153.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/154.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/155.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/156.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/157.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/158.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/159.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/16.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/160.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/161.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/163.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/164.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/165.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/166.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/167.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/168.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/169.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/17.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/170.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/171.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/172.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/173.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/174.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/175.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/176.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/177.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/178.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/179.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/18.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/181.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/182.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/183.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/184.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/185.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/186.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/187.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/188.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/189.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/19.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/190.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/191.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/192.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/193.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/194.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/195.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/196.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/197.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/198.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/199.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/200.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/201.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/202.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/203.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/204.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/205.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/206.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/207.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/208.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/209.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/210.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/211.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/212.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/213.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/214.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/215.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/216.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/217.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/218.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/219.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/220.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/221.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/222.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/223.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset/224.txt
#   inflating: First_Phase_Release(Correction)/First_Phase_Text_Dataset
#   inflating: opendid_test/file59791.txt
#   inflating: opendid_test/file59884.txt
#   inflating: opendid_test/file59981.txt
#   inflating: opendid_test/file60101.txt
#   inflating: opendid_test/file60224.txt
#   inflating: opendid_test/file60338.txt
#   inflating: opendid_test/file60438.txt
#   inflating: opendid_test/file60537.txt
#   inflating: opendid_test/file60590.txt
#   inflating: opendid_test/file60708.txt
#   inflating: opendid_test/file60773.txt
#   inflating: opendid_test/file60836.txt
#   inflating: opendid_test/file60949.txt
#   inflating: opendid_test/file61065.txt
#   inflating: opendid_test/file61218.txt
#   inflating: opendid_test/file61347.txt
#   inflating: opendid_test/file61436.txt
#   inflating: opendid_test/file61638.txt
#   inflating: opendid_test/file61770.txt
#   inflating: opendid_test/file61806.txt
#   inflating: opendid_test/file61933.txt
#   inflating: opendid_test/file62019.txt
#   inflating: opendid_test/file62077.txt
#   inflating: opendid_test/file62170.txt
#   inflating: opendid_test/file62290.txt
#   inflating: opendid_test/file62373.txt
#   inflating: opendid_test/file62496.txt
#   inflating: opendid_test/file62619.txt
#   inflating: opendid_test/file62670.txt
#   inflating: opendid_test/file62798.txt
#   inflating: opendid_test/file62979.txt
#   inflating: opendid_test/file63085.txt
#   inflating: opendid_test/file63184.txt
#   inflating: opendid_test/file63308.txt
#   inflating: opendid_test/file63439.txt
#   inflating: opendid_test/file63551.txt
#   inflating: opendid_test/file63645.txt
#   inflating: opendid_test/file63697.txt
#   inflating: opendid_test/file63794.txt
#   inflating: opendid_test/file63906.txt
#   inflating: opendid_test/file63984.txt
#   inflating: opendid_test/file64010.txt
#   inflating: opendid_test/file64133.txt
#   inflating: opendid_test/file64205.txt
#   inflating: opendid_test/file64270.txt
#   inflating: opendid_test/file64316.txt
#   inflating: opendid_test/file64339.txt
#   inflating: opendid_test/file64455.txt
#   inflating: opendid_test/file64559.txt
#   inflating: opendid_test/file64764.txt
#   inflating: opendid_test/file64900.txt
#   inflating: opendid_test/file65014.txt
#   inflating: opendid_test/file65156.txt
#   inflating: opendid_test/file65296.txt
#   inflating: opendid_test/file65437.txt
#   inflating: opendid_test/file65622.txt
#   inflating: opendid_test/file65693.txt
#   inflating: opendid_test/file65816.txt
#   inflating: opendid_test/file65947.txt
#   inflating: opendid_test/file66075.txt
#   inflating: opendid_test/file66133.txt
#   inflating: opendid_test/file66305.txt
#   inflating: opendid_test/file66350.txt
#   inflating: opendid_test/file66457.txt
#   inflating: opendid_test/file66968.txt
#   inflating: opendid_test/HSA0240.txt
#   inflating: opendid_test/HSA0246.txt
#   inflating: opendid_test/HSA0258.txt
#   inflating: opendid_test/HSA0259.txt
#   inflating: opendid_test/HSA0289.txt
#   inflating: opendid_test/HSA0590.txt

# %%
# !mkdir train_text_data
# !mkdir val_text_data
# !mkdir test_text_data

# %%
# !mv "First_Phase_Release(Correction)" First_Phase_Release

# %%
# !cp /content/First_Phase_Release/First_Phase_Text_Dataset/*.txt train_text_data/
# !cp /content/Second_Phase_Dataset/Second_Phase_Text_Dataset/*.txt train_text_data/
# !cp /content/First_Phase_Release/Validation_Release/*.txt val_text_data/

# %%
# !cp /content/opendid_test/*.txt test_text_data/

# %%
with open('train_answer.txt', 'w') as fw:
  fw.write(open('/content/First_Phase_Release/answer.txt', 'r').read())
  fw.write(open('/content/Second_Phase_Dataset/answer.txt', 'r').read())

with open('val_answer.txt', 'w') as fw:
  fw.write(open('/content/answer.txt', 'r').read())

# %%
import torch
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
#device = torch.device('cpu')

# %%
import pandas as pd
# answer data preprocess

def read_answer_df(path):
  with open(path, 'r') as f:
    answer = f.readlines()
  answer = list(map(lambda x: x.split('\t'), answer))

  columns = ['id_num', 'type', 'start_index', 'end_index', 'content', 'format_date']

  df_dict = {
      'id_num':[],
      'type':[],
      'start_index':[],
      'end_index':[],
      'content':[],
      'format_date':[]
  }

  for content in answer:
    if len(content) not in [5,6]:
      continue
    if len(content) == 6:
      df_dict['format_date'].append(content[5])
    else:
      df_dict['format_date'].append('')

    df_dict['id_num'].append(content[0])
    df_dict['type'].append(content[1])
    df_dict['start_index'].append(int(content[2]))
    df_dict['end_index'].append(int(content[3]))
    df_dict['content'].append(content[4])


  answer_df = pd.DataFrame(df_dict)
  answer_df = answer_df.set_index('id_num')
  return answer_df

# %%
answer_df = read_answer_df('train_answer.txt')
val_answer_df = read_answer_df('val_answer.txt')

# %%
'''
type_list = answer_df['type'].drop_duplicates().tolist()
val_type_list = val_answer_df['type'].drop_duplicates().tolist()
type_list += val_type_list
type_list = list(set(type_list))
type_dict = {t: index + 1 for index, t in enumerate(type_list)}
type_dict['other'] = 0
'''
# Out:
# "\ntype_list = answer_df['type'].drop_duplicates().tolist()\nval_type_list = val_answer_df['type'].drop_duplicates().tolist()\ntype_list += val_type_list\ntype_list = list(set(type_list))\ntype_dict = {t: index + 1 for index, t in enumerate(type_list)}\ntype_dict['other'] = 0\n"

# %%
# force the type dict the same
type_dict = {
  'ORGANIZATION': 1, #STATE V
  'PHI': 2, # ??? PATIENT X (pos)
  'LOCATION-OTHER': 3,#COUNTRY V
  'HOSPITAL': 4,#DATE V
  'PATIENT': 5, # ORGANIZATION V
  'PHONE': 6, #LOCATION-OTHER V
  'IDNUM': 7, #ZIP V
  'ROOM': 8, # ??? ROOM X
  'DATE': 9, #HOSP V
  'STREET': 10, #TIME V
  'DURATION': 11, #DURATION V
  'DEPARTMENT': 12, #DOCTOR V
  'DOCTOR': 13, #PHONE V
  'STATE': 14, #STREET V
  'COUNTRY': 15, # ??? DEPARTMENT X (pos)
  'HOSP': 16, # ??? CITY X (pos)
  'ZIP': 17, #IDNUM V
  'SET': 18, # ??? MEDICALRECORD X (pos)
  'CITY': 19, #HOSPITAL V
  'TIME': 20, #AGE V
  'Nugal\\nHOSPITAL': 21, # ??? Nugal\nHOSPITAL X
  'AGE': 22, #PHI V
  'MEDICALRECORD': 23, #SET V
  'URL': 24, # ??? URL X
  'other': 0
}
type_list = type_list = ['ORGANIZATION', 'PHI', 'LOCATION-OTHER', 'HOSPITAL', 'PATIENT', 'PHONE', 'IDNUM', 'ROOM', 'DATE', 'STREET', 'DURATION', 'DEPARTMENT', 'DOCTOR', 'STATE', 'COUNTRY', 'HOSP', 'ZIP', 'SET', 'CITY', 'TIME', 'Nugal\\nHOSPITAL', 'AGE', 'MEDICALRECORD', 'URL']

# %%
# tokenizer create
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

stage_1_tokenizer = AutoTokenizer.from_pretrained(stage_1_plm)
# Out:
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
train_date_answer_df = answer_df
train_date_answer_df['format_date'] = train_date_answer_df.apply(lambda x: x['format_date'] if len(x['format_date']) == 11 else '', axis=1)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os
import numpy as np
import math

class CasesWindowsDataset(Dataset):
  def __init__(
    self,
    case_dir_path,
    answer_df = None,
    split_type='test'
  ):
    self.case_dir_path = case_dir_path
    self.cases_filelist = os.listdir(case_dir_path)
    if split_type != 'test':
      self.answer_df = answer_df

    self.split_type = split_type
    self.tokenizer = stage_1_tokenizer
    self.windows_size = stage_1_tokenizer.model_max_length

  def __getitem__(self, index):
    filename = self.cases_filelist[index]
    id_num = filename.replace('.txt', '')
    text = open(os.path.join(self.case_dir_path, filename)).read()
    enc_text = self.tokenizer(text, return_offsets_mapping=True, padding=False, truncation=False)
    if self.split_type != 'test':
      return id_num, enc_text, self.answer_df.loc[id_num]
    return id_num, enc_text

  def __len__(self):
    return len(self.cases_filelist)

  def collate_fn(self, batch):
    id_all = []
    y_all = []
    x_all = []

    for b in batch:
      enc_text = b[1]
      token_num = len(enc_text['input_ids'])
      win_num = math.ceil(token_num / self.windows_size)

      for wid in range(win_num):
        wid_enc_text = enc_text.copy()
        for k in wid_enc_text:
          wid_enc_text[k] = wid_enc_text[k][wid*self.windows_size: (wid+1)*self.windows_size]
          if len(wid_enc_text[k]) < self.windows_size: #padding
            pad_cnt = self.windows_size - len(wid_enc_text[k])
            if k == 'input_ids':
              wid_enc_text[k] += [self.tokenizer.pad_token_id] * pad_cnt
            elif k == 'offset_mapping':
              #print(wid_enc_text[k])
              #raise Exception('stop')
              wid_enc_text[k] += [(0, 0)] * pad_cnt
            else:
              wid_enc_text[k] += [0] * pad_cnt


        id_all.append((b[0], wid))
        x_all.append(wid_enc_text)

        if self.split_type != 'test':
          off_map = wid_enc_text['offset_mapping']
          tag_array = np.zeros(len(off_map))
          tag = self.answer_df.loc[b[0]]
          for index, row in tag.iterrows():
            si = row['start_index']
            ei = row['end_index']
            type_text = row['type']
            type_index = type_dict[type_text]
            for index, (s_i, e_i) in enumerate(off_map):
              if e_i > si and s_i < ei:
                tag_array[index] = type_index
          y_all.append(tag_array)
          #torch.tensor(tag_array).to(torch.long).view(1,-1)


    for k in x_all[0]:
      if k == 'offset_mapping':
        x_all[0][k] = torch.cat(list(map(lambda x: torch.tensor(x[k]).view(1, -1, 2), x_all)))
      else:
        x_all[0][k] = torch.cat(list(map(lambda x: torch.tensor(x[k]).view(1, -1), x_all)))

    if self.split_type != 'test':
      y_all = torch.cat(list(map(lambda x: torch.tensor(x).to(torch.long).view(1, -1), y_all)))
      return id_all, x_all[0], y_all
    else:
      return id_all, x_all[0]

    #return id_all, x_all, y_all



train_text_path = 'train_text_data/'
val_text_path = 'val_text_data/'
test_text_path = 'test_text_data/'

#cd = CasesDataset(train_text_path, answer_df, split_type='train')
cd = CasesWindowsDataset(train_text_path, answer_df, split_type='train')
train_dataloader = DataLoader(cd, 2, collate_fn = cd.collate_fn)



val_dataset = CasesWindowsDataset(val_text_path, val_answer_df, split_type='val')
val_dataloader = DataLoader(val_dataset, 2, collate_fn = val_dataset.collate_fn)

test_dataset = CasesWindowsDataset(test_text_path, split_type='test')
test_dataloader = DataLoader(test_dataset, 2, collate_fn = test_dataset.collate_fn)


val_answer_df_clean = val_answer_df[val_answer_df['format_date'] != '']

# %%
from transformers import BertTokenizerFast, BatchEncoding, AutoTokenizer, AutoModelForTokenClassification, AutoModel
from torch import nn
from torch.optim import Adam
from torch.nn import CrossEntropyLoss, MSELoss



class TagModel(nn.Module):
  def __init__(self, tag2idx):
    super().__init__()
    self.tag2idx = tag2idx
    #self.bert_mul = AutoModelForTokenClassification.from_pretrained(pretrain_model, num_labels=len(type_dict))
    self.bert_mul = AutoModelForTokenClassification.from_pretrained(stage_1_plm, num_labels=len(type_dict))
  def forward(self, inputs, labels = None):
    if type(labels) != type(None):
        o = self.bert_mul(**inputs, labels = labels)
    else:
        o = self.bert_mul(**inputs)
    return o


model = TagModel(type_dict)
optimizer = Adam(model.parameters(), lr=3e-5)
# Out:
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#load model (if exist)

if stage_1_model_path:
  model.load_state_dict(torch.load(stage_1_model_path))

# %%
def tag_to_type_list(idx, y_hat, offset_map):
  output_list = []

  tag_index = 0
  start_index = 0
  current_index = -1
  for b_i in range(y_hat.shape[0]):
    b = y_hat[b_i]
    ids, win_num = idx[b_i]
    for index, ti in enumerate(b):
      if ti != tag_index:
        if tag_index != 0:
          output_list.append((ids, type_list[tag_index-1], offset_map[b_i][start_index][0].item(), offset_map[b_i][index - 1][1].item())) #ids, type, si, ei
        tag_index = ti.item() # change slice
        start_index = index

  return output_list

# %%
# stage 1 training (Tag Model)

from tqdm import tqdm

#os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

acc_check_step = 20
epochs = 5

model.to(device)
for epoch in range(epochs):
  if stage_1_training:

    cnt = 0
    c_loss = 0
    c_acc_cnt = 0
    model.train()
    train_output_list = []
    train_tqdm_bar = tqdm(train_dataloader, desc='model training')
    for idx, x, y in train_tqdm_bar:
      x = x.to(device)
      y = y.to(device)
      offset_map = x['offset_mapping']
      del x['offset_mapping']
      o = model(x, labels = y)

      y_hat = o.logits
      y_hat = y_hat.argmax(axis=2)
      output_list = tag_to_type_list(idx, y_hat, offset_map)
      train_output_list += output_list
      loss = o.loss
      c_loss += loss.item()

      loss.backward()
      optimizer.step()
      optimizer.zero_grad()


      cnt += len(y)
      c_acc_cnt += torch.all(torch.eq(y * x['attention_mask'], y_hat * x['attention_mask']), dim=1).int().sum() # exact match

      if cnt % acc_check_step == 0:
        train_tqdm_bar.set_description('Training acc:{:.2f}%, loss:{:.2f}'.format(c_acc_cnt / cnt * 100, c_loss / cnt))


  cnt = 0
  c_loss = 0
  c_acc_cnt = 0
  model.eval()
  val_output_list = []
  val_tqdm_bar = tqdm(val_dataloader, desc='model validation')
  with torch.no_grad():
    for idx, x, y in val_tqdm_bar:
      x = x.to(device)
      y = y.to(device)
      offset_map = x['offset_mapping']
      del x['offset_mapping']
      o = model(x, labels = y)

      y_hat = o.logits
      y_hat = y_hat.argmax(axis=2)
      output_list = tag_to_type_list(idx, y_hat, offset_map)
      val_output_list += output_list

      loss = o.loss
      c_loss += loss.item()

      cnt += len(y)
      c_acc_cnt += torch.all(torch.eq(y * x['attention_mask'], y_hat * x['attention_mask']), dim=1).int().sum() # exact match

      if cnt % acc_check_step == 0:
        val_tqdm_bar.set_description('Validation acc:{:.2f}%, loss:{:.2f}'.format(c_acc_cnt / cnt * 100, c_loss / cnt))
  if not stage_1_training:
    break
# Out:
# model training:   0%|          | 0/867 [00:00<?, ?it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (1291 > 512). Running this sequence through the model will result in indexing errors
# Training acc:91.15%, loss:0.00:  12%|█▏        | 106/867 [01:07<08:01,  1.58it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-22cb8897a8ca> in <cell line: 11>()
#      32       c_loss += loss.item()
#      33
# ---> 34       loss.backward()
#      35       optimizer.step()
#      36       optimizer.zero_grad()
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     490                 inputs=inputs,
#     491             )
# --> 492         torch.autograd.backward(
#     493             self, gradient, retain_graph, create_graph, inputs=inputs
#     494         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     249     # some Python versions print out the first line of a multi-line function
#     250     # calls in the traceback and some print out the last line
# --> 251     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252         tensors,
#     253         grad_tensors_,
#
# KeyboardInterrupt:

# %%
# !mkdir save_model

# %%
# stage 1 model saving
import torch

if stage_1_training:
  torch.save(model.state_dict(), 'save_model/model_{:.2f}.pt'.format(c_acc_cnt / cnt * 100))

# %%
# stage 1 inference
model.eval()
test_output_list = []
test_tqdm_bar = tqdm(test_dataloader, desc='model test')
with torch.no_grad():
  for idx, x in test_tqdm_bar:
    x = x.to(device)
    offset_map = x['offset_mapping']
    del x['offset_mapping']
    o = model(x)

    y_hat = o.logits
    y_hat = y_hat.argmax(axis=2)
    output_list = tag_to_type_list(idx, y_hat, offset_map)
    output_list = list(filter(lambda x: x[2] < x[3], output_list))
    test_output_list += output_list
# Out:
# model test: 100%|██████████| 475/475 [02:23<00:00,  3.32it/s]

# %%
def output_list_to_df(output_list, raw_text_path):
  output_df = pd.DataFrame(output_list, columns=['id_num', 'type', 'start_index', 'end_index'])
  output_df['content'] = ''
  output_df['format_date'] = ''
  for i in range(len(output_df)):
    id_num = output_df.iloc[i]['id_num']
    si = int(output_df.iloc[i]['start_index'])
    ei = int(output_df.iloc[i]['end_index'])
    text = open('{}/{}.txt'.format(raw_text_path, id_num)).read()
    output_df['content'].iloc[i] = text[si:ei]
  return output_df

test_output_df = output_list_to_df(test_output_list, test_text_path)
# Out:
# <ipython-input-26-c4edf38c6726>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['content'].iloc[i] = text[si:ei]

# %%
# output final data
with open('roberta_answer.txt', 'w') as f:
  for i, row in test_output_df.iterrows():
    id_num = row['id_num']
    phi_name = row['type']
    start_pos = row['start_index']
    end_pos = row['end_index']
    phi_value = row['content']
    phi_value = phi_value.replace('\n', '\\n')
    phi_normalized_value = row['format_date']

    if phi_value == '':
      continue
    if id_num == '':
      continue
    if phi_name == '':
      continue

    if phi_name == 'DATE':
      seq = f"{id_num}\t{phi_name}\t{start_pos}\t{end_pos}\t{phi_value}\t{phi_normalized_value}\n"
    else:
      seq = f"{id_num}\t{phi_name}\t{start_pos}\t{end_pos}\t{phi_value}\n"
    f.write(seq)

# %%
from google.colab import files
files.download('roberta_answer.txt')
